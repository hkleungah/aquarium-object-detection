# %%
import os
from pathlib import Path

# %%
PROJECT_PATH = './'                               
WORKSPACE_PATH = PROJECT_PATH + '/workspace'        

TFOD_MODELS_PATH = PROJECT_PATH + '/models'   
PRETRAINED_MODEL_PATH = WORKSPACE_PATH + '/pre_trained_models'

# %%
os.chdir(PROJECT_PATH)
os.getcwd()
# Out:
# 'c:\\Users\\User\\Documents\\gbc\\deep learning ii\\project'

# %%
os.getcwd()
# Out:
# 'c:\\Users\\User\\Documents\\gbc\\deep learning ii\\project'

# %%
Path(PRETRAINED_MODEL_PATH).mkdir(parents=True, exist_ok=True)

# %%
MODEL_TYPE = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'

# %%
#!pip install wget

# %%
os.chdir(PRETRAINED_MODEL_PATH)

import wget # wget is used to download the pretrained model

wget.download('http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz')

# %%
import tarfile

file_name = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
with tarfile.open(file_name, 'r:gz') as tar:
    # extracting all the files
    print('Extracting all the files now...')
    tar.extractall()
    print('Done!')

# %%
if "models" in Path.cwd().parts:
  while "models" in Path.cwd().parts:
    os.chdir(PROJECT_PATH)
elif not Path('models').exists():
  # !git clone https://github.com/tensorflow/models.git

# %%
os.chdir(PROJECT_PATH)
# os.chdir(TFOD_MODELS_PATH + '/research')
os.chdir('workspace/pre_trained_models/models' + '/research')

# %%
##pip install protobuf

# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# 'protoc' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !cp object_detection/packages/tf2/setup.py .

# %%
# !pip install --user .
# Out:
# Processing c:\users\user\documents\gbc\deep learning ii\project\workspace\pre_trained_models\models\research
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached tensorflow-2.10.1-cp38-cp38-win_amd64.whl (455.9 MB)
# ...
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1666500 sha256=7227c1c63937efd08af1d477045ecdf89f9b984baf2f1d6bbd43a745ea640e9b
#   Stored in directory: C:\Users\User\AppData\Local\Temp\pip-ephem-wheel-cache-73es3704\wheels\41\45\34\d8a6a904ed08164664f3458efa6457be300be9687c85ee2c0b
# Successfully built object-detection
# ...
#   Attempting uninstall: object-detection
#     Found existing installation: object-detection 0.1
#     Uninstalling object-detection-0.1:
#       Successfully uninstalled object-detection-0.1
# ...

# %%
os.getcwd()
# Out:
# 'c:\\Users\\User\\Documents\\gbc\\deep learning ii\\project\\workspace\\pre_trained_models\\models\\research'

# %%
# From within models/research/
# !python object_detection/builders/model_builder_tf2_test.py
# Out:
# Running tests under Python 3.8.17: d:\Users\User\anaconda3\envs\tf_gpu_2_11_py_38\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2023-07-21 19:33:17.971411: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-21 19:33:18.396769: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7427 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6
# C:\Users\User\AppData\Roaming\Python\Python38\site-packages\object_detection\builders\model_builder.py:1112: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
# ...
